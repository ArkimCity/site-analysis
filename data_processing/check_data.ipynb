# %%
import json
import pandas as pd

seoul_hospital_path = "../frontend/src/assets/json/seoul_hospital.json"
with open(seoul_hospital_path) as f:
    seoul_hospital_json = json.load(f)

# %%
seoul_hospital_df = pd.DataFrame(
    data=seoul_hospital_json["DATA"], columns=[x.lower() for x in seoul_hospital_json["DESCRIPTION"].keys()]
)

seoul_hospital_df
# Out:
#       dutytime7s                            dutyetc  \
# 0           1000               외과: 상시진료, 내과는 당분간 휴진
# 1           0900                              비만클리닉
# 2           0900                   점심시간 12:30~13:30
# 3           1000        대표번호1 지역번호 추가20170118150453
# 4           0900  진료과목마다 진료시간 다릅니다. 전화 확인 후 방문해주세요.
# ...          ...                                ...
# 19833       0900                   점심시간 13:00~14:00
# 19834       0900                   점심시간 13:00~14:00
# 19835       0900                   점심시간 13:00~14:00
# 19836       0900                   점심시간 13:00~14:00
# 19837       0900                   점심시간 13:00~14:00
#
#                       dutymapimg dutytime1c dutytime3c dutytime5c dutydiv  \
# 0      방이역 1번출구 바로옆 굿모닝 신한증권 뒷건물       1930       1930       1930       C
# 1                   신사역 1번 출구 인근       2000       1900       2000       C
# 2        성신여대입구역 7번출구/ 골든타워 5~6층       1800       1900       1900       B
# ...

# %%
seoul_hospital_json["DESCRIPTION"]
# Out:
# {'DUTYTIME7S': '진료시간(일요일)S',
#  'DUTYETC': '비고',
#  'DUTYMAPIMG': '간이약도',
#  'DUTYTIME1C': '진료시간(월요일)C',
#  'DUTYTIME3C': '진료시간(수요일)C',
#  'DUTYTIME5C': '진료시간(금요일)C',
#  'DUTYDIV': '병원분류',
#  'DUTYTEL3': '응급실전화',
#  'DUTYTEL1': '대표전화1',
#  'DUTYEMCLS': '응급의료기관코드',
#  'DUTYTIME2S': '진료시간(화요일)S',
#  'DUTYTIME7C': '진료시간(일요일)C',
#  'DUTYADDR': '주소',
#  'WORK_DTTM': '작업시간',
#  'POSTCDN2': '우편번호2',
#  'DUTYTIME4S': '진료시간(목요일)S',
#  'POSTCDN1': '우편번호1',
#  'DUTYTIME6S': '진료시간(토요일)S',
#  'DUTYTIME8S': '진료시간(공휴일)S',
#  'DUTYTIME4C': '진료시간(목요일)C',
#  'DUTYTIME2C': '진료시간(화요일)C',
#  'DUTYEMCLSNAME': '응급의료기관코드명',
#  'DUTYTIME6C': '진료시간(토요일)C',
#  'DUTYERYN': '응급실운영여부(1/2)',
#  'WGS84LON': '병원경도',
#  'DUTYINF': '기관설명상세',
#  'DUTYTIME8C': '진료시간(공휴일)C',
#  'DUTYNAME': '기관명',
#  'DUTYTIME3S': '진료시간(수요일)S',
#  'DUTYTIME1S': '진료시간(월요일)S',
#  'HPID': '기관ID',
#  'WGS84LAT': '병원위도',
#  'DUTYTIME5S': '진료시간(금요일)S',
#  'DUTYDIVNAM': '병원분류명'}

# %%
seoul_hospital_df["WGS84LON".lower()]  # 병원경도
seoul_hospital_df["WGS84LAT".lower()]  # 병원위도
set(seoul_hospital_df["DUTYDIVNAM".lower()])  # 병원분류명
# Out:
# {'기타',
#  '기타(구급차)',
#  '병원',
#  '보건소',
#  '요양병원',
#  '의원',
#  '종합병원',
#  '치과병원',
#  '치과의원',
#  '한방병원',
#  '한의원'}

# %%
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "기타"))
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "기타(구급차)"))
print()
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "보건소"))
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "요양병원"))
print()
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "치과의원"))  #
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "치과병원"))  #
print()
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "한의원"))  #
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "한방병원"))  #
print()
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "의원"))  #
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "병원"))  #
print(sum(seoul_hospital_df["DUTYDIVNAM".lower()] == "종합병원"))  #

"""
의원: 29개 이하 병상 - 통상 일반적인 동네 병원
병원: 30개 이상의 병상
종합병원: 100개 이상의 병상 - 7개 또는 9개 이상의 진료과목 (어떤 과이냐에 따라 과목 숫자가 다름)
"""
# Out:
# 17
# 1
#
# 39
# 139
#
# 5133
# 63
#
# 3920
# 92
#
# 10123
# 253
# 58
# '\n의원\n'
